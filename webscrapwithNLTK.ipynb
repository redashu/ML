# %% [markdown]
# <a href="https://colab.research.google.com/github/redashu/ML/blob/master/webscrapwithNLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib  import request   #  for downloading  data from url 
from  bs4  import  BeautifulSoup  #  for souping
import  time 
import  re  #  importing  regular expression 
#  pointing to URL 
#url='https://en.wikipedia.org/wiki/Machine_learning'
url='https://en.wikipedia.org/wiki/2019%E2%80%9320_coronavirus_pandemic'
#url='https://www.php.net/'

htmldata=request.urlopen(url)
#htmldata.read()  # it will download data in html format 
soupdata=BeautifulSoup(htmldata,'html5lib')
#      html data ,  html parser --      
#  what is  HTML parser -- is collection of html tags that can scrape data from particular tag like h1 , html , a , p
#  now selecting a particular tag for data scrape 
atagdata=soupdata.findAll('p')
#  now converting  data into string  format  from HTML format 

mydata=""
for i in atagdata:
  mydata +=  i.text 

#print(mydata)
#  data  cleaning 

#  dATA cleaning
clean_data=re.sub(r'\[[0-9]*\]',' ',mydata)  #  this will remove 0 or more times number appearing in mydata
clean_data=re.sub(r'\s+',' ',clean_data)  # it will remove one or more white spaces with single white space
clean_data=re.sub(r'[^a-zA-Z]',' ',clean_data)  # it will remove single char from starting of the line
clean_data=re.sub(r'\s+',' ',clean_data)  # it will remove one or more white spaces with single white space
print(clean_data)
print(type(clean_data))

#  now lets deal with string 
import time
newdata=clean_data.split()  #  split means conversion of str to  list 

# how to install nltk 
# !pip install nltk
import nltk
# downloading  all dictonary for computer
#nltk.download('all')
#  first removing  the stop words
mypuredata=[]
from nltk.corpus import  stopwords
for i in  newdata:
  if i.lower() not in stopwords.words('english'):
    mypuredata.append(i)

print(mypuredata)
freq_data=nltk.FreqDist(mypuredata)
freq_data.plot(20)  # top 20 words having the most count
# Out:
#  The coronavirus pandemic is an ongoing pandemic of coronavirus disease COVID caused by severe acute respiratory syndrome coronavirus SARS CoV The outbreak was first identified in Wuhan Hubei China in December and was recognised as a pandemic by the World Health Organization WHO on March As of March more than cases of COVID have been reported in over countries and territories resulting in approximately deaths and more than recoveries The virus is typically spread during close contact and via respiratory droplets produced when people cough or sneeze Respiratory droplets may be produced during breathing but the virus is not considered airborne People may also catch COVID by touching a contaminated surface and then their face It is most contagious when people are symptomatic although spread may be possible before symptoms appear The time between exposure and symptom onset is typically around five days but may range from to days Common symptoms include fever cough and shortness of breath Complications may include pneumonia and acute respiratory distress syndrome There is no known vaccine or specific antiviral treatment Primary treatment is symptomatic and supportive therapy Recommended preventive measures include hand washing covering the mouth when coughing maintaining distance from other people and monitoring and self isolation for people who suspect they are infected Efforts to prevent the virus spreading include travel restrictions quarantines curfews event postponements and cancellations and facility closures These include the first arguably successful quarantine of Hubei national or regional quarantines elsewhere in the world curfew measures in China and South Korea various border closures or incoming passenger restrictions screening at airports and train stations and outgoing passenger travel bans Schools and universities have closed either on a nationwide or local basis in more than countries affecting more than billion students The pandemic has led to severe global socioeconomic disruption the postponement or cancellation of sporting religious and cultural events and widespread fears of supply shortages which have spurred panic buying Misinformation and conspiracy theories about the virus have spread online and there have been incidents of xenophobia and racism against Chinese and other East and Southeast Asian people Health authorities in Wuhan the capital of Hubei province China reported a cluster of pneumonia cases of unknown cause on December and an investigation was launched in early January The cases mostly had links to the Huanan Seafood Wholesale Market and so the virus is thought to have a zoonotic origin The virus that caused the outbreak is known as SARS CoV a newly discovered virus closely related to bat coronaviruses pangolin coronaviruses and SARS CoV The earliest known person with symptoms was soon traced back to December someone who did not have visible connections with the later wet market s cluster Of the early cluster of cases reported in December two thirds were found to have a link with the market On March a report from the South China Morning Post said that a year old from Hubei province could have been the first person who contracted the disease on November On February the WHO reported that as new cases reportedly dropped in China but suddenly increased in Italy Iran and South Korea the number of new cases outside China had exceeded the number of new cases in China for the first time There may be substantial underreporting of cases particularly those with milder symptoms By February relatively few cases have been reported among youth with those and under making up of cases worldwide Government sources in Germany and the UK estimate that of the population will need to become infected before effective herd immunity can be achieved A scientific paper from epidemiologists at the University of Oxford modeled the number of cases in the United Kingdom and Italy One of the various different proposed scenari ...
# <class 'str'>
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)
# ['coronavirus', 'pandemic', 'ongoing', 'pandemic', 'coronavirus', 'disease', 'COVID', 'caused', 'severe', 'acute', 'respiratory', 'syndrome', 'coronavirus', 'SARS', 'CoV', 'outbreak', 'first', 'identified', 'Wuhan', 'Hubei', 'China', 'December', 'recognised', 'pandemic', 'World', 'Health', 'Organization', 'March', 'March', 'cases', 'COVID', 'reported', 'countries', 'territories', 'resulting', 'approximately', 'deaths', 'recoveries', 'virus', 'typically', 'spread', 'close', 'contact', 'via', 'respiratory', 'droplets', 'produced', 'people', 'cough', 'sneeze', 'Respiratory', 'droplets', 'may', 'produced', 'breathing', 'virus', 'considered', 'airborne', 'People', 'may', 'also', 'catch', 'COVID', 'touching', 'contaminated', 'surface', 'face', 'contagious', 'people', 'symptomatic', 'although', 'spread', 'may', 'possible', 'symptoms', 'appear', 'time', 'exposure', 'symptom', 'onset', 'typically', 'around', 'five', 'days', 'may', 'range', 'days', 'Common', 'symptoms', 'include', 'fever', 'cough', 'shortness', 'breath', 'Complications', 'may', 'include', 'pneumonia', 'acute', 'respiratory', 'distress', 'syndrome', 'known', 'vaccine', 'specific', 'antiviral', 'treatment', 'Primary', 'treatment', 'symptomatic', 'supportive', 'therapy', 'Recommended', 'preventive', 'measures', 'include', 'hand', 'washing', 'covering', 'mouth', 'coughing', 'maintaining', 'distance', 'people', 'monitoring', 'self', 'isolation', 'people', 'suspect', 'infected', 'Efforts', 'prevent', 'virus', 'spreading', 'include', 'travel', 'restrictions', 'quarantines', 'curfews', 'event', 'postponements', 'cancellations', 'facility', 'closures', 'include', 'first', 'arguably', 'successful', 'quarantine', 'Hubei', 'national', 'regional', 'quarantines', 'elsewhere', 'world', 'curfew', 'measures', 'China', 'South', 'Korea', 'various', 'border', 'closures', 'incoming', 'passenger', 'restrictions', 'screening', 'airports', 'train', 'stations', 'outgoing', 'passenger', 'travel', 'bans', 'Schools', 'universities', 'closed', 'either', 'nationwide', 'local', 'basis', 'countries', 'affecting', 'billion', 'students', 'pandemic', 'led', 'severe', 'global', 'socioeconomic', 'disruption', 'postponement', 'cancellation', 'sporting', 'religious', 'cultural', 'events', 'widespread', 'fears', 'supply', 'shortages', 'spurred', 'panic', 'buying', 'Misinformation', 'conspiracy', 'theories', 'virus', 'spread', 'online', 'incidents', 'xenophobia', 'racism', 'Chinese', 'East', 'Southeast', 'Asian', 'people', 'Health', 'authorities', 'Wuhan', 'capital', 'Hubei', 'province', 'China', 'reported', 'cluster', 'pneumonia', 'cases', 'unknown', 'cause', 'December', 'investigation', 'launched', 'early', 'January', 'cases', 'mostly', 'links', 'Huanan', 'Seafood', 'Wholesale', 'Market', 'virus', 'thought', 'zoonotic', 'origin', 'virus', 'caused', 'outbreak', 'known', 'SARS', 'CoV', 'newly', 'discovered', 'virus', 'closely', 'related', 'bat', 'coronaviruses', 'pangolin', 'coronaviruses', 'SARS', 'CoV', 'earliest', 'known', 'person', 'symptoms', 'soon', 'traced', 'back', 'December', 'someone', 'visible', 'connections', 'later', 'wet', 'market', 'cluster', 'early', 'cluster', 'cases', 'reported', 'December', 'two', 'thirds', 'found', 'link', 'market', 'March', 'report', 'South', 'China', 'Morning', 'Post', 'said', 'year', 'old', 'Hubei', 'province', 'could', 'first', 'person', 'contracted', 'disease', 'November', 'February', 'reported', 'new', 'cases', 'reportedly', 'dropped', 'China', 'suddenly', 'increased', 'Italy', 'Iran', 'South', 'Korea', 'number', 'new', 'cases', 'outside', 'China', 'exceeded', 'number', 'new', 'cases', 'China', 'first', 'time', 'may', 'substantial', 'underreporting', 'cases', 'particularly', 'milder', 'symptoms', 'February', 'relatively', 'cases', 'reported', 'among', 'youth', 'making', 'cases', 'worldwide', 'Government', 'sources', 'Germany', 'UK', 'estimate', 'population', 'need', 'become', 'infected', 'effective', 'herd', 'immunity', 'achieved', 'scientific', 'paper', 'epidemiologi ...
